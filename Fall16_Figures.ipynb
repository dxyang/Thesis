# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %matplotlib inline

# %%
N = 3
ind = np.arange(N)  # the x locations for the groups
width = 0.45       # the width of the bars

fig, ax = plt.subplots()

io_test_means = (0.03555979, 0.022218654, 0.021825504)
io_test_stddev = (0.000571887, 0.000279264, 0.000127266)
rects1 = ax.bar(ind, io_test_means, width, color='r', yerr=io_test_stddev)

io_train_means = (0.01900228, 0.017608224, 0.017746568)
io_train_stddev = (0.000378367, 0.000181483, 0.000132467)
rects2 = ax.bar(ind + width, io_train_means, width, color='y', yerr=io_train_stddev)

# add some text for labels, title and axes ticks
ax.set_ylabel('Mean Squared Error')
ax.set_title('Formulations of Input and Output')
ax.set_xticks(ind + width)
ax.set_xticklabels(('Left to Right', 'Left to Original', 'Blanked to Original'))
ax.legend((rects1[0], rects2[0]), ('Test', 'Train'))

plt.show()

# %%
xbottleneck_16 = np.arange(16, 592, 16)

testL2_bottleneck_16 = [ 0.06547201, 0.06569653, 0.06552945, 0.03009419, 0.0251329, 0.02395721, 
                        0.02288385, 0.02182935, 0.02136500, 0.02131077, 0.0207140, 0.02055385,
                        0.02080400, 0.02043439, 0.02081851, 0.02039931, 0.0205530, 0.02039222, 
                        0.02028646, 0.02019968, 0.02042418, 0.02050229, 0.02046111, 0.0203261, 
                        0.02045344, 0.02015463, 0.02023706, 0.02017974, 0.02023458, 0.02055499,
                        0.02070384, 0.02040488, 0.02042831, 0.02040611, 0.0202734, 0.02051732 ]
trainL2_bottleneck_16 = [ 0.06756010,  0.06754307,  0.06754539,  0.02776016,  0.02236820,  0.02070255,
                         0.01940022,  0.01714483,  0.01673273,  0.01612019,  0.01555019,  0.01489062,
                         0.01379799,  0.01419329,  0.01329869,  0.01360202,  0.01286202,  0.01243837,
                         0.01261566,  0.01331981,  0.01191515,  0.01100861,  0.0117864,   0.01076296,
                         0.0106674,   0.01183657,  0.01107267,  0.01147167,  0.01037509,  0.00965615, 
                         0.01017289,  0.01024598,  0.01047078,  0.00980586,  0.00931496, 0.00976414 ]
xbottleneck_2 = np.arange(54, 64, 2)
testL2_bottleneck_2 = [ 0.06563298, 0.03309317, 0.03236739, 0.02954304, 0.02959928 ]
trainL2_bottleneck_2 = [ 0.06755228,  0.03106217,  0.03033635,  0.02747135,  0.02741035 ]

# %%
# plot test accuracy
fig, ax = plt.subplots()

plt.figure(1)
plt.scatter(xbottleneck_16, testL2_bottleneck_16, c='r',label="Test")
plt.scatter(xbottleneck_2, testL2_bottleneck_2, c='r')
plt.scatter(xbottleneck_16, trainL2_bottleneck_16, c='b',label='Train')
plt.scatter(xbottleneck_2, trainL2_bottleneck_2, c='b')
legend = ax.legend(loc='upper right', shadow=True)

plt.title("Mean Squared Error vs Autoencoder Bottleneck Size", fontsize=14)
plt.ylabel("Mean Squared Error", fontsize=14)
plt.xlabel("Bottleneck Size", fontsize=14)
#plt.savefig('test.png')
plt.show()

# %%
test_removerows =  np.array([[ 0.01857653,  0.01581957,  0.01626435],
                             [ 0.01726955],
                             [ 0.01434063,  0.01484321],
                             [ 0.01517755,  0.01593098],
                             [ 0.01496726],
                             [ 0.01699585,  0.0150026],
                             [ 0.01466943],
                             [ 0.01554503,  0.01495628],
                             [ 0.01676544,  0.01656142,  0.01576694],
                             [ 0.01618412,  0.01639127,  0.01672984,  0.01630657],
                             [ 0.01666866,  0.01829688,  0.01705271],
                             [ 0.01846869,  0.01745387],
                             [ 0.01963055,  0.01971721,  0.01965214,  0.02021723,  0.02022226],
                             [ 0.02225431,  0.02168015,  0.02231735],
                             [ 0.02466661,  0.02440618,  0.02440249],
                             [ 0.02804561],
                             [ 0.03158146,  0.03111178,  0.03136298,  0.03140553],
                             [ 0.03658546,  0.03627898,  0.03652057,  0.03662914],
                             [ 0.04306116,  0.04313239,  0.04312184],
                             [ 0.05064902,  0.04989251,  0.05059502],
                             [ 0.05556581,  0.05571101,  0.05576405],
                             [ 0.06008083,  0.06024629,  0.05997091],
                             [ 0.0631211 ],
                             [ 0.06565806,  0.06565857,  0.06559104,  0.06564433,  0.06568337],
                             [ 0.06563398,  0.06550484,  0.06593717,  0.06543646,  0.06561045],
                             [ 0.06556886,  0.0657832,  0.06583409,  0.0656682,   0.06552145],
                             [ 0.0656708,   0.06578027,  0.06564596,  0.06553621,  0.06570224]])
train_removerows = np.array([[ 0.0174988,   0.01463891,  0.01513809],
                             [ 0.016136],
                             [ 0.01327795,  0.01377195],
                             [ 0.0139645,   0.01513564],
                             [ 0.01411591],
                             [ 0.01602804,  0.01407482],
                             [ 0.01364505],
                             [ 0.01436791,  0.01389616],
                             [ 0.01538342,  0.01528876,  0.01433105],
                             [ 0.01462853,  0.01487032,  0.01524193,  0.01474393],
                             [ 0.01481706,  0.01652749,  0.0151873],
                             [ 0.01632908,  0.01512398],
                             [ 0.01662617,  0.01688654,  0.01687048,  0.01754231,  0.01753128],
                             [ 0.0181232,   0.01813125,  0.01802352],
                             [ 0.01940535,  0.01895796,  0.01870235],
                             [ 0.0221701],
                             [ 0.02396627,  0.02450337,  0.02411222,  0.02450458],
                             [ 0.02809639,  0.0287687,   0.02726128,  0.02722589],
                             [ 0.03372177,  0.03455405,  0.03336843],
                             [ 0.04049863,  0.04255814,  0.04016734],
                             [ 0.04874489,  0.04915421,  0.04811968],
                             [ 0.05604792,  0.05538698,  0.05640297],
                             [ 0.06210621],
                             [ 0.0675393,   0.06753717,  0.06754545,  0.06756049,  0.06755675],
                             [ 0.06753841,  0.06755145,  0.06759102,  0.06755928,  0.06753442],
                             [ 0.06755878,  0.06756712,  0.06758943,  0.06754687,  0.06754939],
                             [ 0.0675603,   0.0675611,   0.0675543,   0.06753644,  0.06754336]])

test_means_removerows = np.zeros(27)
train_means_removerows = np.zeros(27)
for i in range(27):
    test_means_removerows[i] = np.mean(test_removerows[i])
    train_means_removerows[i] = np.mean(train_removerows[i])

# %%
test_mmse_removerows = np.array([  4.07370995e-05,   1.43425297e-04,   4.69495445e-04,   1.24779443e-03,
   2.84890284e-03,   5.32241386e-03,   8.53820014e-03,   1.25567842e-02,
   1.75687615e-02,   2.31680817e-02,   2.95210766e-02,   3.56241626e-02,
   4.16047050e-02,   4.68837833e-02,   5.23039904e-02,   5.71204388e-02,
   6.19485959e-02,   6.67584361e-02,   7.13113315e-02,   7.55176991e-02,
   7.80227490e-02,   7.85520010e-02,   7.81629249e-02,   7.60604684e-02,
   7.33610273e-02,   7.06890561e-02,   6.80104467e-02])
train_mmse_removerows = np.array([  1.39669621e-05,   1.11349200e-04,   4.34285547e-04,   1.21245663e-03,
   2.71365264e-03,   5.04312280e-03,   8.13673464e-03,   1.19679965e-02,
   1.64509484e-02,   2.16537029e-02,   2.74809687e-02,   3.31518034e-02,
   3.82632554e-02,   4.30648013e-02,   4.78975335e-02,   5.26703041e-02,
   5.75176574e-02,   6.27099067e-02,  6.76222170e-02,   7.17624726e-02,
   7.50415300e-02,   7.70809990e-02,   7.80608091e-02,   7.72608864e-02,
   7.51651505e-02,  7.26177336e-02,   7.00135761e-02])

# %%
# plot test accuracy 
fig, ax = plt.subplots()
plt.figure(1)
plt.scatter(np.arange(1,28), test_means_removerows, c='r', label='Test NN')
plt.scatter(np.arange(1,28), train_means_removerows, c='b', label='Train NN')
plt.scatter(np.arange(1,28), test_mmse_removerows, c='g', label='Test MMSE')
plt.scatter(np.arange(1,28), train_mmse_removerows, c='c', label='Test MMSE')
legend = ax.legend(loc='upper left', shadow=True)

plt.title("Hiding Columns from Right Side of Image", fontsize=14)
plt.ylabel("Mean Squared Error", fontsize=14)
plt.xlabel("Columns Hidden", fontsize=14)
#plt.savefig('test.png')
plt.show()

# %%
testL2_squares = np.array(
[[ 0.01514185,  0.01599119,  0.01606253],
 [ 0.01568538],
 [ 0.01604304,  0.01596195,  0.01597153,  0.01621697],
 [ 0.01573002,  0.01641842,  0.01603358],
 [ 0.01744986,  0.01748288],
 [ 0.01983102,  0.02028473,  0.01963183],
 [ 0.02361763],
 [ 0.03044453],
 [ 0.03848857,  0.03853912],
 [ 0.04928312,  0.0493255,   0.04892413],
 [ 0.05816777],
 [ 0.06285769],
 [ 0.06582846,  0.06545911,  0.0655883,   0.06553113,  0.06546065],
 [ 0.07563103,  0.06551212,  0.06595444,  0.06552251,  0.06546891]]
    )
trainL2_squares = np.array(
[[ 0.01389086,  0.01487126,  0.01489795],
 [ 0.01431685],
 [ 0.01472168,  0.01469903,  0.01466341,  0.01477422],
 [ 0.01421747,  0.01478798,  0.01423158],
 [ 0.01532494,  0.01533595],
 [ 0.0165884,   0.01734529,  0.01635459],
 [ 0.01800065],
 [ 0.0215684 ],
 [ 0.02760035,  0.02832777],
 [ 0.04350712,  0.04403639,  0.04349504],
 [ 0.05630046],
 [ 0.0637336],
 [ 0.06756458,  0.06756768,  0.06753074,  0.06755772,  0.06757826],
 [ 0.07898875,  0.06753726,  0.06762527,  0.06753109,  0.06753772]]
    )

test_means_removecenter = np.zeros(14)
train_means_removecenter = np.zeros(14)
for i in range(14):
    test_means_removecenter[i] = np.mean(testL2_squares[i])
    train_means_removecenter[i] = np.mean(trainL2_squares[i])

# %%
# from MSE_columns_square_sizes.ipynb
test_mmse_removecenter = np.array([ 0.03178387,  0.07095345,  0.09311441,  0.10973924,  0.11738725,  0.12608947,
  0.13051252,  0.1320572,   0.12582779,  0.11902688,  0.10760543,  0.09823191,
  0.08141908,  0.06558285])
train_mmse_removecenter = np.array([ 0.02415308,  0.05114388,  0.06988564,  0.08024208,  0.08728272,  0.09312629,
  0.09803643,  0.1003484,   0.10058864,  0.10114657,  0.09492837,  0.08707787,
  0.07768026,  0.06752108])

# %%
# plot test accuracy 
fig, ax = plt.subplots()
plt.figure(1)
squareAreas = np.multiply(np.arange(2,30,2),np.arange(2,30,2))
ax.scatter(squareAreas, test_means_removecenter, c='r', label='Test NN')
ax.scatter(squareAreas, train_means_removecenter, c='b',label='Train NN')
ax.scatter(squareAreas, test_mmse_removecenter, c='g', label='Test MMSE')
ax.scatter(squareAreas, train_mmse_removecenter, c='c', label='Train MMSE')
legend = ax.legend(loc='lower right', shadow=True)

plt.title("Hiding Squares from Center of Image", fontsize=14)
plt.ylabel("Mean Squared Error", fontsize=14)
plt.xlabel("Size of Square Hidden (pixels)", fontsize=14)
plt.show()
