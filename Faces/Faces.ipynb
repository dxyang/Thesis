# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from utils import *
from glob import glob
import os
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
genImgs = np.load('imgs.npy')
shiftedGenImgs = (genImgs + 1.0)/2.0

# %%
print genImgs.shape
# Out:
# (64, 64, 64, 3)

# %%
for i in range(10):
    plt.figure(i)
    plt.imshow(shiftedGenImgs[i])

# %%
# data = glob(os.path.join("./data", "lfw","*", "*.jpg"))
data = glob(os.path.join("./data", "celebA", "*.jpg"))
idx = 10
batch = 64

print len(data)

train, test = train_test_split(data, test_size=0.2, random_state=42)
print len(train)
print len(test)
print train[:10]
print test[:10]
# Out:
# 202599
# 162079
# 40520
# ['./data/celebA/113249.jpg', './data/celebA/023581.jpg', './data/celebA/000963.jpg', './data/celebA/076096.jpg', './data/celebA/028958.jpg', './data/celebA/073705.jpg', './data/celebA/198760.jpg', './data/celebA/120590.jpg', './data/celebA/168045.jpg', './data/celebA/023815.jpg']
# ['./data/celebA/008078.jpg', './data/celebA/115380.jpg', './data/celebA/022181.jpg', './data/celebA/024447.jpg', './data/celebA/184976.jpg', './data/celebA/181550.jpg', './data/celebA/095670.jpg', './data/celebA/015164.jpg', './data/celebA/102085.jpg', './data/celebA/133555.jpg']

# %%
# np.save("train_imgPaths.npy", train)
train_paths = np.load("train_imgPaths.npy")
print train_paths[0]
# Out:
# ./data/celebA/113249.jpg

# %%
batch_files = data[idx*batch:(idx+1)*batch]
print batch_files[:5]
batch = [
  get_image(batch_file,
            input_height=100,
            input_width=100,
            resize_height=64,
            resize_width=64,
            is_crop=True) for batch_file in batch_files]
batch_images = np.array(batch).astype(np.float32)
batch_images += 1.0
batch_images /= 2.0
print batch_images.shape
# Out:
# ['./data/celebA/014041.jpg', './data/celebA/114487.jpg', './data/celebA/076935.jpg', './data/celebA/181187.jpg', './data/celebA/034584.jpg']
# (64, 64, 64, 3)

# %%
for i in range(10):
    plt.figure(i)
    plt.imshow(batch_images[i])

# %%
mask = np.ones((64, 64, 3))
maskMatrix =np.tile(mask, (1, 50))

# %%
print mask.shape

# %%
print maskMatrix.shape

# %%
mask[16:48, 16:48, :] = 0
print np.sum(mask[:, :, 0])

# %%
matrix = np.resize(mask, [10, 64, 64, 3])

# %%
print matrix.shape

# %%
print (matrix[0][47:49, 47:49, 2])
